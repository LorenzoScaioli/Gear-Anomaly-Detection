# %% [markdown]
# # Preprocess of the dataset ROBOFLOW

# %% [markdown]
# #### Create the binary masks for each image from the annotation file (COCO standard)

# %%
import json
import os
import cv2
import numpy as np

def create_mask_from_annotations(json_path, output_mask_dir): 
    os.makedirs(output_mask_dir, exist_ok=True)

    # === UPLOAD FILE JSON COCO ===
    with open(json_path, "r") as f:
        coco = json.load(f)

    image_info = {img['id']: (img['file_name'], img['width'], img['height']) for img in coco['images']}

    # temporary dictionary to hold masks
    masks = {}  # image_id -> mask (np.ndarray)

    # For each image, create a mask
    for ann in coco['annotations']:
        image_id = ann['image_id']
        bbox = ann['bbox']  # [x, y, width, height]
        x, y, w, h = map(int, bbox)

        file_name, width, height = image_info[image_id]

        # If the image_id is not in masks, create a new mask all black (no annotations)
        if image_id not in masks:
            mask = np.zeros((height, width), dtype=np.uint8)
            masks[image_id] = mask
        else:
            mask = masks[image_id]

        # Draw a white rectangle within the image bounds
        cv2.rectangle(mask, (x, y), (x + w, y + h), 255, thickness=-1)  # filled rectangle

    # Save masks to the output directory
    for image_id, mask in masks.items():
        file_name, _, _ = image_info[image_id]
        base_name = os.path.splitext(file_name)[0]
        out_path = os.path.join(output_mask_dir, f"{base_name}.png")
        cv2.imwrite(out_path, mask)

    # if image not in masks create a mask all black
    for image_id, (file_name, width, height) in image_info.items():
        if image_id not in masks:
            mask = np.zeros((height, width), dtype=np.uint8)
            base_name = os.path.splitext(file_name)[0]
            out_path = os.path.join(output_mask_dir, f"{base_name}.png")
            cv2.imwrite(out_path, mask)

# %%
input_folder = "robodata_original"
output_folder = "robodata_original"

for folder in ["test", "train", "valid"]:
    json_path = os.path.join(input_folder, folder,"_annotations.coco.json")
    output_mask_dir = os.path.join(output_folder, folder, "masks")
    create_mask_from_annotations(json_path, output_mask_dir)

# %% [markdown]
# #### Central crop of 1024x1024 of the orginal image
# Before cropping remove 200px from each side because there are other objects in some images

# %%
import cv2
import numpy as np

def center_crop_gear(image, mask, output_size=1024):
    # Remove 200 pixels from each side
    image = image[200:-200, 200:-200]
    mask = mask[200:-200, 200:-200]

    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image.copy()

    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        raise ValueError("Nessun contorno trovato.")

    # Find the largest contour, i.e. the gear
    main_contour = max(contours, key=cv2.contourArea)

    # Computethe centroid of the main contour
    M = cv2.moments(main_contour)
    if M["m00"] == 0:
        raise ValueError("Momento nullo.")
    cx = int(M["m10"] / M["m00"])
    cy = int(M["m01"] / M["m00"])

    # Compute the cropping box
    half = output_size // 2
    top = max(cy - half, 0)
    bottom = min(cy + half, image.shape[0])
    left = max(cx - half, 0)
    right = min(cx + half, image.shape[1])

    # crop the image and mask
    cropped = image[top:bottom, left:right]
    cropped_mask = mask[top:bottom, left:right]

    # Add padding to ensure the output size is output_size x output_size
    final = np.ones((output_size, output_size, 3), dtype=np.uint8) * 255  # white background
    y_offset = (output_size - cropped.shape[0]) // 2
    x_offset = (output_size - cropped.shape[1]) // 2
    final[y_offset:y_offset + cropped.shape[0], x_offset:x_offset + cropped.shape[1]] = cropped

    # Add padding to mask
    final_mask = np.ones((output_size, output_size), dtype=np.uint8) * 255  # white background
    final_mask[y_offset:y_offset + cropped_mask.shape[0], x_offset:x_offset + cropped_mask.shape[1]] = cropped_mask
    
    return final, final_mask

# %%
import os

input_folder = "robodata_original"
output_folder = "robodata_cropped"
os.makedirs(output_folder, exist_ok=True)

for folder in ["test", "train", "valid"]:
    input_subfolder = os.path.join(input_folder, folder)
    output_subfolder = os.path.join(output_folder, folder)
    os.makedirs(output_subfolder, exist_ok=True)
    os.makedirs(os.path.join(output_subfolder, "masks"), exist_ok=True)

    for filename in os.listdir(input_subfolder):
        if filename.endswith(".jpg"):
            img = cv2.imread(os.path.join(input_subfolder, filename))
            mask = cv2.imread(os.path.join(input_subfolder, "masks", filename.replace(".jpg", ".png")), cv2.IMREAD_GRAYSCALE)
            
            cropped_img, cropped_mask = center_crop_gear(img, mask, 1024)
            cv2.imwrite(os.path.join(output_subfolder, filename), cropped_img)
            cv2.imwrite(os.path.join(output_subfolder, "masks", filename), cropped_mask)

# %% [markdown]
# #### Create the median image for each gear
# To do so we have already centered the gear in the image, we will take the image and rotate it of 1/16 of 360° because there are 16 teeth in the gear. After the rotation we use the cv2.findTransformECC fucntion that find the best euclidian transformation (transation and rotation) to best match the original image and the rotated one. In this way the two images will now overlap. <br>
# In this way we will create the median image, i.e. the image that represents the "perfect" teeth of the gear as it is the median over all the teaths of the gear.

# %%
import cv2
import numpy as np
BG_COLOR = (255, 255, 255)

def align_img(img, target_img):
    """Allinea l'immagine di input all'immagine di destinazione usando ECC."""
    ref_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    tgt_gray = cv2.cvtColor(target_img, cv2.COLOR_BGR2GRAY)

    warp_matrix = np.eye(2, 3, dtype=np.float32)

    # Optimization criteria for ECC (Enhanced Correlation Coefficient)
    criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 2000, 1e-5)

    # Align the image with ECC
    _, warp_matrix = cv2.findTransformECC(ref_gray, tgt_gray, warp_matrix, cv2.MOTION_EUCLIDEAN, criteria)

    # Apply the transformation to the mask
    aligned_img = cv2.warpAffine(img, warp_matrix, (target_img.shape[1], target_img.shape[0]), flags=cv2.INTER_NEAREST, borderValue=BG_COLOR)

    return aligned_img

def create_rotated_median(image_path, num_rotations=16):
    image = cv2.imread(image_path)
    h, w = image.shape[:2]
    center = (w // 2, h // 2)
    rotated_images = []

    # Precompute rotation matrices to save time
    rotation_matrices = [
        cv2.getRotationMatrix2D(center, i * (360 / num_rotations), 1.0)
        for i in range(num_rotations)
    ]
    flag=True
    for rot_mat in rotation_matrices:
        rotated = cv2.warpAffine(image, rot_mat, (w, h), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=BG_COLOR)
        try:
            aligned = align_img(rotated, image)
        except:
            print(f"Alignment failed for {image_path}")
            aligned = image
            flag=False
        rotated_images.append(aligned)

    # Stack and compute median along axis 0 (per pixel)
    if flag:
        stacked = np.stack(rotated_images).astype(np.float32)
        median_image = np.median(stacked, axis=0).astype(np.uint8)
        return median_image

# %%
import os 

# folder = "robodata_cropped"

for folder in ["test", "train", "valid"]:
    folder = f"robodata_cropped/{folder}"
    os.makedirs(os.path.join(folder, "median"), exist_ok=True)

    for filename in os.listdir(folder):
        if filename.endswith(".jpg"):
            
            if os.path.exists(os.path.join(folder, "median", filename)):
                print(f"Median image already exists for {filename}")
                continue

            img_path = os.path.join(folder, filename)
            median_result = create_rotated_median(img_path)

            if median_result is not None:
                cv2.imwrite(os.path.join(folder, "median", filename), median_result)
            else:
                print(f"Median image creation failed for {img_path}")
# Out:
# Median image already exists for teeth_broken_25726_jpg.rf.1dbc9520dfa94b0f93f84e8eeb32a260.jpg
# Median image already exists for teeth_broken_25729_jpg.rf.7add0d9431740d8fe3ff6882c2689d35.jpg
# Median image already exists for teeth_broken_25735_jpg.rf.5cf4f0b01ee828626d156c8830f082e5.jpg
# Median image already exists for teeth_broken_25740_jpg.rf.d6f00132c9be5301cb6ed4133ab5937a.jpg
# Median image already exists for teeth_broken_25756_jpg.rf.93c3bfc0a90f8d281f9100243624711b.jpg
# Median image already exists for teeth_broken_25759_jpg.rf.311cef41a2f7d262c7bf120e5fee7b0d.jpg
# Median image already exists for teeth_broken_25774_jpg.rf.ed459039788ca837552cd59351841b6a.jpg
# Median image already exists for teeth_broken_25779_jpg.rf.ce57d0849da8a8a1c36475d40542568f.jpg
# Median image already exists for teeth_broken_25822_jpg.rf.71b5dad464ba32533aeceb358b51acec.jpg
# Median image already exists for teeth_broken_25825_jpg.rf.c6814849da7ab5e9233ddd92bdcbb7c8.jpg
# Median image already exists for teeth_broken_25831_jpg.rf.a4ea61e9a8e8b789a0d16ab5d8cc15f2.jpg
# Median image already exists for teeth_broken_25842_jpg.rf.f38f411b20a8355a1050408a352b35e1.jpg
# Median image already exists for teeth_broken_25846_jpg.rf.493bc90c33db639fc1fca0cad3726ae7.jpg
# Median image already exists for teeth_broken_25852_jpg.rf.0af53c0397966aebbc61c661a962d6de.jpg
# Median image already exists for teeth_broken_25858_jpg.rf.4d9beeafb3451e5ae9b716711878d161.jpg
# Median image already exists for teeth_broken_25888_jpg.rf.4ef11a32a3d3354c85d6e29b67ac732e.jpg
# Median image already exists for teeth_broken_25909_jpg.rf.9afabd3be4e313b5b65a484a0b5053fe.jpg
# Median image already exists for teeth_broken_25915_jpg.rf.6e1e7bef9622171166106a2f4745d404.jpg
# Median image already exists for teeth_broken_25923_jpg.rf.f77d6f46a6325c21e8dffc080272b68f.jpg
# Median image already exists for teeth_broken_25932_jpg.rf.3da3f441cb3db970b3eda53434534abc.jpg
# Median image already exists for teeth_broken_25941_jpg.rf.9cd348d7dc80811948bd1b397c0e6812.jpg
# Median image already exists for teeth_broken_25942_jpg.rf.9aafd255f6fa1197bcbe29b2a85fde3d.jpg
# Median image already exists for teeth_broken_25948_jpg.rf.14c9a3722726c27eaf746c6dcc73a221.jpg
# Median image already exists for teeth_broken_25951_jpg.rf.20bcfdab94593ee29d4b9cb058cd284d.jpg
# Median image already exists for teeth_broken_26343_jpg.rf.f94ea4557b2123bddaa291e73ebd6f84.jpg
# Median image already exists for teeth_broken_26350_jpg.rf.ae3a25287f0b00bcfbc42c5bb91b5efd.jpg
# Median image already exists for teeth_broken_26355_jpg.rf.6ac672b10382277e40e877b06fa52d24.jpg
# Median image already exists for teeth_broken_26356_jpg.rf.eb535d37ffe16f3abf693f0feddc9e86.jpg
# Median image already exists for teeth_broken_26385_jpg.rf.548b57ff8032846a21188417fe2ea8b9.jpg
# Median image already exists for teeth_broken_26395_jpg.rf.c0aa6931e434946755c95073a23dab63.jpg
# Median image already exists for teeth_broken_26407_jpg.rf.9fd9a4dfa71307cebacc7c4f75181226.jpg
# Median image already exists for teeth_broken_26422_jpg.rf.bff353f106c034a63874b1cf5a79c6d2.jpg
# Median image already exists for teeth_broken_26425_jpg.rf.2ad3fb66ed520473661c5864726ddce0.jpg
# Median image already exists for teeth_broken_26446_jpg.rf.0a08971a0d19d397c125aa7a892acf54.jpg
# Median image already exists for teeth_broken_26449_jpg.rf.ff7803ffdca99aaf267b7b9f1787ffd5.jpg
# Median image already exists for teeth_broken_26458_jpg.rf.4af3f5c7fd84fd7f7d81d2fd74a3086c.jpg
# Median image already exists for teeth_broken_26463_jpg.rf.5eea411d6ecba70f6648704f7265f01b.jpg
# Median image already exists for teeth_broken_26467_jpg.rf.1cd2b6c0ab8950b74ce65349c8d25692.jpg
# Median image already exists for teeth_broken_26473_jpg.rf.4f878966015326500b62dc41a1d31c8f.jpg
# Median image already exists for teeth_broken_26476_jpg.rf.2c5179c7c3c9873280aabaa6ea9eb365.jpg
# Median image already exists for teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c.jpg
# Median image already exists for teeth_broken_26487_jpg.rf.ab5ef4809d9a876ac513800ed1a8e0ce.jpg
# Median image already exists for teeth_broken_26493_jpg.rf.7dc9c0abf4ba1e199c496412196e83d0.jpg
# Median image already exists for teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768.jpg
# Median image already exists for teeth_broken_26497_jpg.rf.e3ca8c8c5218665524841ab16b1f0c74.jpg
# Median image already exists for teeth_broken_26506_jpg.rf.b8731d7cd49c07e56fb0738c1614f7d5.jpg
# Median image already exists for teeth_broken_26511_jpg.rf.d95339a7d3834c53c50afc00b2b595c5.jpg
# Median image already exists for teeth_broken_26515_jpg.rf.995292136a2f375131053ddb6288a0fb.jpg
# Median image already exists for teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746.jpg
# Median image already exists for teeth_broken_26524_jpg.rf.08da360159b87b964e58618467fc4315.jpg
# Median image already exists for teeth_broken_26529_jpg.rf.c421483ffba296da8c717dba26ba7924.jpg
# Median image already exists for teeth_broken_26532_jpg.rf.6ba5c1327c3ff7c6a05f309e9d97c0e9.jpg
# Median image already exists for teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341.jpg
# Median image already exists for teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d.jpg
# Median image already exists for teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364.jpg
# Median image already exists for teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24.jpg
# Median image already exists for teeth_broken_26550_jpg.rf.38abf1c771181afaf66af28d8fcdebb5.jpg
# Median image already exists for teeth_broken_26559_jpg.rf.7424a7b58ef5844a8ad2321055feed30.jpg
# Median image already exists for teeth_broken_26560_jpg.rf.ee5c1c850bf95390e134202799e10cbc.jpg
# Median image already exists for teeth_broken_26577_jpg.rf.e378704b5478391c2952da89a33554de.jpg
# Median image already exists for teeth_broken_26578_jpg.rf.9f5a6a4a8ceef865cf30ff740e61b451.jpg
# Median image already exists for teeth_broken_26581_jpg.rf.5f02f367e5cae66df280acdc9f8f4ac2.jpg
# Median image already exists for teeth_broken_26584_jpg.rf.18fac285accce4b0b1b7868f1c3a4c1e.jpg
# Median image already exists for teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689.jpg
# Median image already exists for teeth_broken_26589_jpg.rf.81b4d81980b0764ca08280363d38f9a6.jpg
# Median image already exists for teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647.jpg
# Median image already exists for teeth_broken_26598_jpg.rf.375871598946b14d7e646afb9963a8cc.jpg
# Median image already exists for teeth_broken_26601_jpg.rf.45c8d7d7571400c5d72b9d7123647e44.jpg
# Median image already exists for teeth_broken_26611_jpg.rf.ac0d0e09d59c9a00fc8452ce6b8dd61e.jpg
# Median image already exists for teeth_broken_26619_jpg.rf.262a89d4d2c8f55905a954c6daa3ccd7.jpg
# Median image already exists for teeth_broken_26629_jpg.rf.b480bdb28cbb93666bbeb642b099d255.jpg
# Median image already exists for teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b.jpg
# Median image already exists for teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd.jpg
# Median image already exists for teeth_broken_26637_jpg.rf.715587c18dbb62d6878747416cf8fe3d.jpg
# Median image already exists for teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4.jpg
# Median image already exists for teeth_broken_26646_jpg.rf.15d8018ebc7b1bf01bf0b2e3b53e251d.jpg
# Median image already exists for teeth_broken_26649_jpg.rf.1ada9d719189ee73947f467d7958b3d7.jpg
# Median image already exists for teeth_broken_26658_jpg.rf.e99714c819f483630826f288ec1c3dc7.jpg
# Median image already exists for teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133.jpg
# Median image already exists for teeth_broken_26676_jpg.rf.edfdff04e18b8c97adde1c7f284c5b9a.jpg
# Median image already exists for 26250_jpg.rf.7aedc201b13ab2f32bb434c2d8050007.jpg
# Median image already exists for 34719_jpg.rf.e4d6624a6336f354dac7544e0c15a60a.jpg
# Median image already exists for 34720_jpg.rf.79c5e32ea34501a016e7e0a40a5606c4.jpg
# Median image already exists for 34728_jpg.rf.ef60d305aedef4b089788843bb348cf1.jpg
# Median image already exists for 34729_jpg.rf.cd5bc16edf94a040c961788acbdacf1b.jpg
# Median image already exists for 34734_jpg.rf.bd55d3b357e512b4530a60cc9f7c3fe2.jpg
# Median image already exists for 34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7.jpg
# Median image already exists for 34738_jpg.rf.4fa72a50fabef926f40c7c5a1673e770.jpg
# Median image already exists for 34744_jpg.rf.88054799cb338bbdbe153c8791e517e8.jpg
# Median image already exists for 34750_jpg.rf.7a60f2fde9f74cbac42f6f84554d445b.jpg
# Median image already exists for 34753_jpg.rf.97b11a55bea9a6bf7f332b02ef497349.jpg
# Median image already exists for 34756_jpg.rf.dcfad2689967fac10e9b759a6f61a5e1.jpg
# Median image already exists for 34758_jpg.rf.82508e33dfb49f4bd10ef702e8b4256a.jpg
# Median image already exists for 34759_jpg.rf.ea52ae68e325c99882937bf08f8fd0cf.jpg
# Median image already exists for 34761_jpg.rf.fc6a0650ba504beb1671f3adc0408da0.jpg
# Median image already exists for 34762_jpg.rf.133c41249716afe3a82758e7f112e695.jpg
# Median image already exists for 34767_jpg.rf.ee3092c46998f4db29ffe637e7037f93.jpg
# Median image already exists for 34773_jpg.rf.fea85e5198e002560915dbbbb5d1b3b8.jpg
# Median image already exists for 34774_jpg.rf.c428fefc46fcc73c922d2988416312bf.jpg
# Median image already exists for 34779_jpg.rf.194416acd48eb5290ae6773cefce258d.jpg
# Median image already exists for 34782_jpg.rf.75eacfe2ed57d0c3a20253ec23d06f8d.jpg
# Median image already exists for 34786_jpg.rf.bf7ad21bb9f3ce7216da1d71964592ea.jpg
# Median image already exists for 34788_jpg.rf.c838fa42db1fbdab4bd0fb8565ad6b15.jpg
# Median image already exists for 34789_jpg.rf.730f8265e5abbac792c5fedb363ac68e.jpg
# Median image already exists for 34791_jpg.rf.d4e3cd24e818eb5e15f3a84db231eb55.jpg
# Median image already exists for 34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f.jpg
# Median image already exists for 34806_jpg.rf.fb87634a244afa8f7ee208598ddccaf9.jpg
# Median image already exists for 34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40.jpg
# Median image already exists for 34810_jpg.rf.b28099c635e0c45156dd469f90049cf2.jpg
# Median image already exists for 34813_jpg.rf.afe732298b0c61f31de9bbc66da421ee.jpg
# Median image already exists for 34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307.jpg
# Median image already exists for 34818_jpg.rf.121f448665590ba5df8a074b04c5ad63.jpg
# Median image already exists for 34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1.jpg
# Median image already exists for 34827_jpg.rf.d02a953f0a2ca443d8f81698b25d8506.jpg
# Median image already exists for 34881_jpg.rf.a222e5d0b6b9737eb0c85d1362de8cca.jpg
# Median image already exists for 34882_jpg.rf.ad9997a37e83fa38ffeb67115f16f2b9.jpg
# Median image already exists for 34890_jpg.rf.e8daf9b182affd75a31182f7a8e3524c.jpg
# Median image already exists for 34891_jpg.rf.37aacfb4758e428d227acd2320704c23.jpg
# Median image already exists for 34893_jpg.rf.1981b7bc071fcaf0fe027f4a1f0faf6f.jpg
# Median image already exists for 34899_jpg.rf.b6b609fb8547b145209e929ec4c9e10c.jpg
# Median image already exists for 34902_jpg.rf.9975e1c9c684b4526c26de47b11f7762.jpg
# Median image already exists for 34903_jpg.rf.77bf01d7ab2d2498155cab0b00abf59a.jpg
# Median image already exists for 34906_jpg.rf.60253914ae80c2e04c5ed74e7af1a64b.jpg
# Median image already exists for 34914_jpg.rf.2975502ed28f7c2e9165d7251108cad3.jpg
# Median image already exists for 34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a.jpg
# Median image already exists for 34923_jpg.rf.06b472870aff2c868c665bc945539928.jpg
# Median image already exists for 34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf.jpg
# Median image already exists for 34930_jpg.rf.f73405a1929a8ad37fc0d5ed38f48680.jpg
# Median image already exists for 34938_jpg.rf.ab2783d82f483960644ec79f4384dc09.jpg
# Median image already exists for 34941_jpg.rf.402d503b06c3eb9283225c6397ea73e1.jpg
# Median image already exists for 34948_jpg.rf.28d5a667d486ecb6f44cf6ca8e4d006d.jpg
# Median image already exists for 34951_jpg.rf.55aac589e3f1167c1878198e8f4dd0d9.jpg
# Median image already exists for 34953_jpg.rf.5d8d9f6309476218a5219a77289ecb2e.jpg
# Median image already exists for 34956_jpg.rf.1ca865eebb7c59e71715674c9271878b.jpg
# Median image already exists for 34957_jpg.rf.916065d5b03dbd084f47ecac529e67c4.jpg
# Median image already exists for 34960_jpg.rf.bae91ff61867f3bf2db43779226a00a2.jpg
# Median image already exists for 34963_jpg.rf.84ecd41ad2c2fb911f287845e5035b3f.jpg
# Median image already exists for 34968_jpg.rf.0f923754cf0bfec3b8a72e528fe4afb1.jpg
# Median image already exists for 34969_jpg.rf.eb38fbe9f9bea812a51c749816ec9fdb.jpg
# Median image already exists for 34974_jpg.rf.73065b924dba6cb94bec1c7fe43a22f2.jpg
# Median image already exists for 34975_jpg.rf.97051cc2972fbb6c492529e953e2e829.jpg
# Median image already exists for 34977_jpg.rf.67e43bcf5b0ded57579d9022288977d3.jpg
# Median image already exists for 34980_jpg.rf.be2a29cb31c6f5ca6ef118b074aeb25b.jpg
# Median image already exists for 34983_jpg.rf.5ff11363981b0587d2dc84fe32539208.jpg
# Median image already exists for 34986_jpg.rf.fe4b23b200e4399063e6503bdecf3fef.jpg
# Median image already exists for 34990_jpg.rf.10c40c8ac646c2bac202be1b9e570ca2.jpg
# Median image already exists for 34993_jpg.rf.d84df733169b831da8fdd8dee7eb5dff.jpg
# Median image already exists for 34998_jpg.rf.15dad0b5ea35c263f2fa7ab5ea9f0ce5.jpg
# Median image already exists for 34999_jpg.rf.31d7ed6de63ffe47156d5c9a33f7adda.jpg
# Median image already exists for 35001_jpg.rf.7f4c70e981eb6d639c0441cbbeb5688b.jpg
# Median image already exists for 35002_jpg.rf.6e7cf31e145b17a18a679b71044b8a06.jpg
# Median image already exists for 35004_jpg.rf.094087a27411b886d739ffb3e700b024.jpg
# Median image already exists for 35007_jpg.rf.1d48a5122c0eacd4930ddfa372873d8d.jpg
# Median image already exists for 35010_jpg.rf.02df5044607d36a36dbdc12162e3f992.jpg
# Median image already exists for 35013_jpg.rf.66027678c98eb36b26fc4de72d449bdd.jpg
# Median image already exists for 35014_jpg.rf.72d7dc711ccf3cdfdf43bcbea0790a56.jpg
# Median image already exists for 35017_jpg.rf.0f37f5b5ecc40657f1d8e31a224d99f0.jpg
# Median image already exists for 35022_jpg.rf.48049ffda76f56825ac206322da61063.jpg
# Median image already exists for 35023_jpg.rf.03bb8c14899f425ad25df02e0aa17b8d.jpg
# Median image already exists for land_broken_23931_jpg.rf.c18947b6d69e6df469248696efc9fcd0.jpg
# Median image already exists for land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd.jpg
# Median image already exists for land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835.jpg
# Median image already exists for land_broken_23938_jpg.rf.60a6cd4dfc3322dbfc7345b9c4701abc.jpg
# Median image already exists for land_broken_23947_jpg.rf.444645e87b4babdb3f817a6e0b793243.jpg
# Median image already exists for land_broken_23949_jpg.rf.2b6ba6aa213ecc89f5d0461eb5f187bc.jpg
# Median image already exists for land_broken_23950_jpg.rf.fa6d9e0dce4f0ded378dc28079fb9080.jpg
# Median image already exists for land_broken_23953_jpg.rf.360f5a8cd8034a6fc6c4bfb02ed44539.jpg
# Median image already exists for land_broken_23958_jpg.rf.7130825580c617919adb66e645bdb78c.jpg
# Median image already exists for land_broken_23959_jpg.rf.51e26aff1efe84bb412b0e5d0dea9f43.jpg
# Median image already exists for land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68.jpg
# Median image already exists for land_broken_23967_jpg.rf.ca4981f26b03d1d4aef06ae7e61d13e2.jpg
# Median image already exists for land_broken_23971_jpg.rf.f32abe1e51add121ca0d609ded3a1af4.jpg
# Median image already exists for land_broken_23973_jpg.rf.b8493ad8c7b1963533026c67aa1e28e0.jpg
# Median image already exists for land_broken_23974_jpg.rf.a633889476c440c7f918fc74d2ea4eaa.jpg
# Median image already exists for land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477.jpg
# Median image already exists for land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b.jpg
# Median image already exists for land_broken_23985_jpg.rf.612af1b2b7ce75d1746123ec75b9dba8.jpg
# Median image already exists for land_broken_23986_jpg.rf.d11444fe8e7f65eb4dc9739ac342992f.jpg
# Median image already exists for land_broken_23989_jpg.rf.5e872523260226760ecd9d27dda18fae.jpg
# Median image already exists for land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff.jpg
# Median image already exists for land_broken_23992_jpg.rf.8ed54218f215ec850a246987d962f391.jpg
# Median image already exists for land_broken_23995_jpg.rf.46c30cffcd70cd0e9ede606e8b7211a0.jpg
# Median image already exists for land_broken_23998_jpg.rf.1e9b75c7f3dd611397dc878a75ef24f9.jpg
# Median image already exists for land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05.jpg
# Median image already exists for land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7.jpg
# Median image already exists for land_broken_24013_jpg.rf.02cae472bd937b917cb0b7e03ff69fe1.jpg
# Median image already exists for land_broken_24018_jpg.rf.bb222b086ba29c2a11121e2f7e18b5cd.jpg
# Median image already exists for land_broken_24019_jpg.rf.88965e23cbd1ecd2b56444442717f00e.jpg
# Median image already exists for land_broken_24022_jpg.rf.f52c53858cc7464ef438d7219c050984.jpg
# Median image already exists for land_broken_24031_jpg.rf.3dd0f465c958ef06f818ec0c92e7323c.jpg
# Median image already exists for land_broken_24033_jpg.rf.fca598ff35395975ef19cc2f22d2b3c9.jpg
# Median image already exists for land_broken_24034_jpg.rf.c8b3a019ade882f4142f3040547aabfb.jpg
# Median image already exists for land_broken_24036_jpg.rf.4af970c0c90c73ab1840825e817e6eb1.jpg
# Median image already exists for land_broken_24037_jpg.rf.813d802f9a858c254c559bc87e38ce21.jpg
# Median image already exists for land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0.jpg
# Median image already exists for land_broken_24046_jpg.rf.9154b47505cfacaf5fde0919bdfd9811.jpg
# Median image already exists for land_broken_24051_jpg.rf.fcb0df78f2a740e9d00b4a42fadb0f1e.jpg
# Median image already exists for land_broken_24052_jpg.rf.df24cc3f13c1d770ed815dc5908de2e4.jpg
# Median image already exists for land_broken_24055_jpg.rf.b755b6c96026ace4544021e271c186aa.jpg
# Median image already exists for land_broken_24058_jpg.rf.279ec24cad74d5210bc8c51915d94a18.jpg
# Median image already exists for land_broken_24069_jpg.rf.9fd507bccb2a611fc90feb7f4c064ac9.jpg
# Median image already exists for land_broken_24070_jpg.rf.1ce7d18fec391e7c53ccbab8c00bcc87.jpg
# Median image already exists for land_broken_24073_jpg.rf.2392d67c20ed8f1021d5ec61d702f199.jpg
# Median image already exists for land_broken_24078_jpg.rf.224fdfdfd58d8d49e761aa1ef4822fed.jpg
# Median image already exists for land_broken_24082_jpg.rf.13f13abbe7774e4dcf1e4a7de1a0cd94.jpg
# Median image already exists for land_broken_24091_jpg.rf.ed42c3ddc25ff16db33faa551aaef4be.jpg
# Median image already exists for land_broken_24093_jpg.rf.4ec12cb7fa442c11a8edec4205e4eac7.jpg
# Median image already exists for land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35.jpg
# Median image already exists for land_broken_24096_jpg.rf.27d9492b47157da4d0eeeb521b551dc1.jpg
# Median image already exists for land_broken_24097_jpg.rf.919e13d690e75da0dee44f25ebc736f5.jpg
# Median image already exists for land_broken_24105_jpg.rf.52c70f5c35661db710a31dc43618494a.jpg
# Median image already exists for land_broken_24106_jpg.rf.355d227d46b0ac0d19a1e47aa404a76c.jpg
# Median image already exists for land_broken_24114_jpg.rf.37c32cbd4eca977627840ac466a739cd.jpg
# Median image already exists for land_broken_24117_jpg.rf.5e25a4903cc44914c760eb174193cf51.jpg
# Median image already exists for land_broken_24120_jpg.rf.9e28e3149fdcfb5629b9e0f3cd8851a3.jpg
# Median image already exists for land_broken_24127_jpg.rf.f40821be622eb3e15b9da32b0e580fd5.jpg
# Median image already exists for land_broken_24132_jpg.rf.02e06b71f4703070bf577e071d11abbb.jpg
# Median image already exists for land_broken_24135_jpg.rf.4b8b1ee6c4d78c72404b8ed111aae997.jpg
# Median image already exists for land_broken_24136_jpg.rf.3316f80b2e18f52751146cfe4293de2f.jpg
# Median image already exists for land_broken_24144_jpg.rf.bc1aeabc4bd99a9fce8417bea6344b8a.jpg
# Median image already exists for land_broken_24151_jpg.rf.2f98a5a41650c14eb9622c9bc5a4986e.jpg
# Median image already exists for land_broken_24154_jpg.rf.67996b2b36ec541b8abbef5f1dae534d.jpg
# Median image already exists for land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26.jpg
# Median image already exists for land_broken_24159_jpg.rf.7808923a4efa4338655e8af82637c27d.jpg
# Median image already exists for land_broken_24163_jpg.rf.5e038b53db705379a2e2ba7b7f607a1f.jpg

# %% [markdown]
# #### Create standard notation A B label

# %%
# save: median in A, imgs in B, masks in label
input_folder = "robodata_cropped"
output_folder = "robodata_standardized"

os.makedirs(output_folder, exist_ok=True)
for out_sub_folder in ["A", "B", "label"]:
    os.makedirs(os.path.join(output_folder, out_sub_folder), exist_ok=True)

for subfolder in ["test", "train", "valid"]:
    subfolder_med_path = os.path.join(input_folder, subfolder, "median")

    for filename in os.listdir(subfolder_med_path):
        if filename.endswith(".jpg"):
            # Copy the median image in folder A
            src_path = os.path.join(subfolder_med_path, filename)
            dst_path = os.path.join(output_folder, "A", filename.replace(".jpg", ".png"))
            cv2.imwrite(dst_path, cv2.imread(src_path))

            # Copy the image in folder B
            src_path = os.path.join(input_folder, subfolder, filename)
            dst_path = os.path.join(output_folder, "B", filename.replace(".jpg", ".png"))
            cv2.imwrite(dst_path, cv2.imread(src_path))

            # Copia la maschera nella cartella label
            mask_src_path = os.path.join(input_folder, subfolder, "masks", filename)
            mask_dst_path = os.path.join(output_folder, "label", filename.replace(".jpg", ".png"))
            cv2.imwrite(mask_dst_path, cv2.imread(mask_src_path))

# %% [markdown]
# # Augment and reduce dataset
#
# Split the dataset in train/val/test, then divide each image of 1024x1024 in 4 images 512x512, then we'll apply data augmentation

# %%
import os
import random

def split_filenames(input_dir, output_dir, train_ratio=0.7, val_ratio=0.2, test_ratio=0.1, seed=42):
    os.makedirs(output_dir, exist_ok=True)

    filenames = [f for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]

    # Shuffle for randomness
    random.seed(seed)
    random.shuffle(filenames)

    total = len(filenames)
    train_end = int(total * train_ratio)
    val_end = train_end + int(total * val_ratio)

    # Split the list
    train_files = filenames[:train_end]
    val_files = filenames[train_end:val_end]
    test_files = filenames[val_end:]

    # Rename files
    train_files = ['train_'+line for line in train_files]
    val_files = ['val_'+line for line in val_files]
    test_files = ['test_'+line for line in test_files]

    # Write to .txt files that contain the filenames for each split
    with open(os.path.join(output_dir, 'train.txt'), 'w') as f:
        f.write('\n'.join(train_files))

    with open(os.path.join(output_dir, 'val.txt'), 'w') as f:
        f.write('\n'.join(val_files))

    with open(os.path.join(output_dir, 'test.txt'), 'w') as f:
        f.write('\n'.join(test_files))

    print(f"Saved train/val/test splits to: {output_dir}")

def rename_files(folder_dir):
    for split in ['train', 'val', 'test']:
        with open(os.path.join(folder_dir, 'list', split+'.txt'), 'r') as f:
            lines = f.read().splitlines()
        for file_name in lines:
            old_file_name = file_name.split('_', 1)[1]
            for sub_folder in ['A', 'B', 'label']:
                old_path = os.path.join(folder_dir, sub_folder, old_file_name)
                new_path = os.path.join(folder_dir, sub_folder, split+'_'+old_file_name)

                os.rename(old_path, new_path)

# %%
import shutil

input_folder = "robodata_standardized"
output_folder = "Dataset_ROBOFLOW"

# Copy the folder and all its contents
shutil.copytree(input_folder, output_folder)
# Out:
# 'Dataset_ROBOFLOW'

# %%
tmp_input = os.path.join(output_folder, "A").replace('\\', '/')
tmp_output = os.path.join(output_folder, "list").replace('\\', '/')

split_filenames(input_dir=tmp_input, output_dir=tmp_output)
rename_files(folder_dir=output_folder)
# Out:
# Saved train/val/test splits to: Dataset_ROBOFLOW/list

# %% [markdown]
# Define the function to divide in 4 the images and to do data augmentation

# %%
import os
import random
import cv2


INPUT_SIZE = 1024
OUT_SIZE = INPUT_SIZE//2

def crop_and_save_image(image_path, output_dir):
    img_name = os.path.basename(image_path).replace('\\', '/')
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Failed to load image from: {image_path}")

    height, width, _ = image.shape

    # Check for expected dimensions
    if height != INPUT_SIZE or width != INPUT_SIZE:
        raise ValueError(f"Expected image size {INPUT_SIZE}x{INPUT_SIZE}, got {width}x{height}")

    # Define coordinates for the 4 crops
    crops = [
        (0, 0),                 # Top-left
        (0, OUT_SIZE),          # Top-right
        (OUT_SIZE, 0),          # Bottom-left
        (OUT_SIZE, OUT_SIZE)    # Bottom-right
    ]

    for i, (y, x) in enumerate(crops):
        cropped = image[y:y+OUT_SIZE, x:x+OUT_SIZE]
        output_path = os.path.join(output_dir, f"{img_name[:-4]}_{i+1}.png").replace('\\', '/')
        cv2.imwrite(output_path, cropped)
        print(f"Saved: {output_path}")

def update_filenames_list(input_folder, output_folder):
    '''
    In input folder A with the median images, in output the list folder where the 3 .txt files will be
    '''
    for split in ['train', 'val', 'test']:
        output_file_path = os.path.join(output_folder, split+'.txt')
        open(output_file_path, 'w').close()

    for img_name in os.listdir(input_folder):
        for split in ['train', 'val', 'test']:
            if split in img_name[:5]:
                output_file_path = os.path.join(output_folder, split+'.txt')
                with open(output_file_path, 'a') as g:  # 'a' means append
                    g.write(img_name + '\n')

# %% [markdown]
# create the folder "_splitted" where we'll save the divided images, then define the .txt files in the "list" folder

# %%
input_dir = "Dataset_ROBOFLOW"
output_dir = "Dataset_ROBOFLOW_cropped"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)
for folder in ["A", "B", "label", "list"]:
    fold_path = os.path.join(output_dir, folder).replace('\\', '/')
    os.makedirs(fold_path, exist_ok=True)

for filename in os.listdir(os.path.join(input_dir, 'A')):
    for folder in ["A", "B", "label"]:
        file_path = os.path.join(input_dir, folder, filename).replace('\\', '/')
        output_sub_dir = os.path.join(output_dir, folder).replace('\\', '/')
        crop_and_save_image(image_path=file_path, output_dir=output_sub_dir)

update_filenames_list(input_folder=os.path.join(output_dir, 'A'), output_folder=os.path.join(output_dir, 'list'))
# Out:
# Saved: Dataset_ROBOFLOW_cropped/A/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34735_jpg.rf.64a1fb8d516e877f479d1074a6806fb7_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34801_jpg.rf.860788605e9cdb34ffeb288d3fc41b7f_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34809_jpg.rf.0a4b09b7d748d738fc79d3596306dc40_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34815_jpg.rf.9b1e4f7b8855db79ddb2873743530307_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34824_jpg.rf.c22f963b8dc3462ecfc339bec7b1e1c1_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34920_jpg.rf.4ef6daeeee37bd00d338396e8bab1f0a_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_34927_jpg.rf.5860cd50d74cefb0e47bb4ed0de41fdf_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_35004_jpg.rf.094087a27411b886d739ffb3e700b024_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23932_jpg.rf.d9ba37407a29d6f1615aa05796dc0fbd_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23935_jpg.rf.de1f7609ee3896a91f0b2ac76e976835_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23962_jpg.rf.e6e8f16a01d6577cc0d76a9379dc1f68_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23976_jpg.rf.021523e9efab572b16b45443bfc33477_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23977_jpg.rf.b7153e41a44b2d3795bea79b901fa99b_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_23991_jpg.rf.6d7d95434e5c12e848013f3c25f7e0ff_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24009_jpg.rf.bb1f9ec00ea83b1187fa152e3fb67e05_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24010_jpg.rf.8965c7bcf5b8a5c37da718df383efda7_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24045_jpg.rf.b9df34c791130e3d4797c797a8b895f0_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24094_jpg.rf.c5581376a465946e0bff8bc920842f35_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24156_jpg.rf.c45c8c726c14605f8341b1d16c863f26_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24229_jpg.rf.69c89ea34c8c7de4e854d7127dcd4cbf_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24247_jpg.rf.301da156f462da7046dd8a2a5401bcd0_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24271_jpg.rf.7b4fe323da2bdbfda5ab773df73563cb_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24361_jpg.rf.19dafd1abea68929da0680e2a11c5808_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24382_jpg.rf.eb24531db0b483e49f68f4ad63eb47e3_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24442_jpg.rf.4adb37d8df7de51eeaa20877ff8f3d69_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24453_jpg.rf.85c5693089eecbda1dd331f88264ff04_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24457_jpg.rf.81847942987f320e264297785b7ae61b_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24471_jpg.rf.d2309ff6882af3ed212ddfe0453c9379_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24492_jpg.rf.512a56296463c729d83f6a3d875167c0_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24508_jpg.rf.54a6b47cf612aa9909c67cca08f26ea2_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24550_jpg.rf.f2e09d330e7535a97155b656aa26b9d5_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24625_jpg.rf.2aea3a2ad5c9f9d9bf4793c07de384c3_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24669_jpg.rf.8c5cb60c9947d2be09fd37b665fd4c10_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24681_jpg.rf.4d1b1eded5e06dbaf7c20e3268551eeb_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24723_jpg.rf.342bca71c5bdd158fc5f05b1648bb695_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24738_jpg.rf.063edca57b9c2b1e3734c5e9f9779402_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24886_jpg.rf.0cbd332cd4df3ec5e46c21fa6de48297_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24903_jpg.rf.b77c53bf22abda9b1857a6f0dcacc6cc_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/test_land_broken_24918_jpg.rf.7341005eb8230f81de263648743c85fa_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24964_jpg.rf.41e6d7fee6c314dc8d065440b7e25aa6_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24964_jpg.rf.41e6d7fee6c314dc8d065440b7e25aa6_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/test_land_broken_24964_jpg.rf.41e6d7fee6c314dc8d065440b7e25aa6_3.png
# ...
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26481_jpg.rf.4f259a2664a770f080c46ce18ef8271c_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26494_jpg.rf.8e35c30898b7ab0ef55a6924cc21d768_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26521_jpg.rf.bdfa4166a6cc053d6750d87734ccf746_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26533_jpg.rf.c21bb46c892cc7be2fad3cbc7ff49341_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26536_jpg.rf.66300681217644bb1c022757affc575d_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26538_jpg.rf.cfd1f7fba77a98f88cf5d601c7ff2364_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26542_jpg.rf.7db6cb49531a15548c98eb866ecdaf24_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26587_jpg.rf.32962088d7a329c9b2f98fc92ccc8689_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26593_jpg.rf.08b842c3d4436492acfd882e826ae647_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26632_jpg.rf.c39aa6f4bf1794970e753740ff21363b_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26635_jpg.rf.c390562bc6e5eb90fe8e81ba453875dd_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26641_jpg.rf.3eab4dbba8be0d73b6577312d05955b4_4.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_1.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_2.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_3.png
# Saved: Dataset_ROBOFLOW_cropped/A/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_4.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_1.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_2.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_3.png
# Saved: Dataset_ROBOFLOW_cropped/B/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_4.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_1.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_2.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_3.png
# Saved: Dataset_ROBOFLOW_cropped/label/val_teeth_broken_26659_jpg.rf.a5eef47009908b9141ffbaee71f28133_4.png

# %% [markdown]
# Create a new folder "_augmented" where we store the images after applying the following augmentation methods in 3 phases:
# 1) All possible combinations:
#    - Rotations (90,180,270)
#    - save the original image (0 degree)

# %%
import os
import cv2
import numpy as np

BG_img = 255
BG_mask = 0

def save_and_apply_transformations(img_A_path, img_B_path, mask_path, img_A_output_dir, img_B_output_dir, mask_output_dir, copy=False,
                          small_translation=False, nr_small_translation:int=1, zoom=False, nr_zoom:int=1,
                          horizontal_flip=False, vertical_flip=False, rotations=False, rotation_angles:list=None, rotation_center:list=None,
                          noise=False):
    
    image_A = cv2.imread(img_A_path, cv2.IMREAD_GRAYSCALE)
    image_B = cv2.imread(img_B_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    filename = os.path.basename(img_A_path)

    if copy:
        img_A_output_path = os.path.join(img_A_output_dir, filename)
        img_B_output_path = os.path.join(img_B_output_dir, filename)
        mask_output_path = os.path.join(mask_output_dir, filename)
        
        cv2.imwrite(img_A_output_path, image_A)
        cv2.imwrite(img_B_output_path, image_B)
        cv2.imwrite(mask_output_path, mask)
    
    if small_translation:
        for i in range(nr_small_translation):
            img_A_output_path = os.path.join(img_A_output_dir, filename[:-4]+f"_trans{i+1}.png")
            img_B_output_path = os.path.join(img_B_output_dir, filename[:-4]+f"_trans{i+1}.png")
            mask_output_path = os.path.join(mask_output_dir, filename[:-4]+f"_trans{i+1}.png")
            
            tx = np.random.randint(-10, 10)  # Random trnsalation between -5 and +5 pixel
            ty = np.random.randint(-10, 10)
            M = np.float32([[1, 0, tx], [0, 1, ty]])
            translated_A = cv2.warpAffine(image_A, M, (image_A.shape[1], image_A.shape[0]), borderValue=BG_img)
            translated_B = cv2.warpAffine(image_B, M, (image_B.shape[1], image_B.shape[0]), borderValue=BG_img)
            translated_mask = cv2.warpAffine(mask, M, (mask.shape[1], mask.shape[0]), borderValue=BG_mask)
            
            cv2.imwrite(img_A_output_path, translated_A)
            cv2.imwrite(img_B_output_path, translated_B)
            cv2.imwrite(mask_output_path, translated_mask)

    if zoom:
        for i in range(nr_zoom):
            img_A_output_path = os.path.join(img_A_output_dir, filename[:-4]+f"_zoom{i+1}.png")
            img_B_output_path = os.path.join(img_B_output_dir, filename[:-4]+f"_zoom{i+1}.png")
            mask_output_path = os.path.join(mask_output_dir, filename[:-4]+f"_zoom{i+1}.png")

            (h, w) = image_A.shape[:2]
            center = (w // 2, h // 2)
            zoom_factor = np.random.uniform(0.9, 1.1)
            M = cv2.getRotationMatrix2D(center, 0, zoom_factor)
            zoomed_A = cv2.warpAffine(image_A, M, (w, h), borderValue=BG_img)
            zoomed_B = cv2.warpAffine(image_B, M, (w, h), borderValue=BG_img)
            zoomed_mask = cv2.warpAffine(mask, M, (w, h), borderValue=BG_mask)

            cv2.imwrite(img_A_output_path, zoomed_A)
            cv2.imwrite(img_B_output_path, zoomed_B)
            cv2.imwrite(mask_output_path, zoomed_mask)
    
    if horizontal_flip:
        img_A_output_path = os.path.join(img_A_output_dir, filename[:-4]+"_flipH.png")
        img_B_output_path = os.path.join(img_B_output_dir, filename[:-4]+"_flipH.png")
        mask_output_path = os.path.join(mask_output_dir, filename[:-4]+"_flipH.png")

        flipped_A = cv2.flip(image_A, 1)
        flipped_B = cv2.flip(image_B, 1)
        flipped_mask = cv2.flip(mask, 1)

        cv2.imwrite(img_A_output_path, flipped_A)
        cv2.imwrite(img_B_output_path, flipped_B)
        cv2.imwrite(mask_output_path, flipped_mask)

    if vertical_flip:
        img_A_output_path = os.path.join(img_A_output_dir, filename[:-4]+"_flipV.png")
        img_B_output_path = os.path.join(img_B_output_dir, filename[:-4]+"_flipV.png")
        mask_output_path = os.path.join(mask_output_dir, filename[:-4]+"_flipV.png")

        flipped_A = cv2.flip(image_A, 0)
        flipped_B = cv2.flip(image_B, 0)
        flipped_mask = cv2.flip(mask, 0)

        cv2.imwrite(img_A_output_path, flipped_A)
        cv2.imwrite(img_B_output_path, flipped_B)
        cv2.imwrite(mask_output_path, flipped_mask)
        
    if rotations:
        if rotation_angles is None:
            print("rotation angles not defined")
        else:
            for angle in rotation_angles:
                img_A_output_path = os.path.join(img_A_output_dir, filename[:-4]+f"_rot{angle}.png")
                img_B_output_path = os.path.join(img_B_output_dir, filename[:-4]+f"_rot{angle}.png")
                mask_output_path = os.path.join(mask_output_dir, filename[:-4]+f"_rot{angle}.png")
                
                (h, w) = image_A.shape[:2]
                if rotation_center is None:
                    center = (w // 2, h // 2)
                else:
                    center=rotation_center
                scale = 1.0
                M = cv2.getRotationMatrix2D(center, angle, scale)
                rotated_A = cv2.warpAffine(
                    image_A, M, (w, h),
                    flags=cv2.INTER_LINEAR,
                    borderMode=cv2.BORDER_CONSTANT,
                    borderValue=(BG_img, BG_img, BG_img) if len(image_A.shape) == 3 else BG_img
                )
                rotated_B = cv2.warpAffine(
                    image_B, M, (w, h),
                    flags=cv2.INTER_LINEAR,
                    borderMode=cv2.BORDER_CONSTANT,
                    borderValue=(BG_img, BG_img, BG_img) if len(image_A.shape) == 3 else BG_img
                )
                rotated_mask = cv2.warpAffine(
                    mask, M, (w, h),
                    flags=cv2.INTER_LINEAR,
                    borderMode=cv2.BORDER_CONSTANT,
                    borderValue=(BG_mask, BG_mask, BG_mask) if len(mask.shape) == 3 else BG_mask
                )

                cv2.imwrite(img_A_output_path, rotated_A)
                cv2.imwrite(img_B_output_path, rotated_B)
                cv2.imwrite(mask_output_path, rotated_mask)

    if noise:
        img_A_output_path = os.path.join(img_A_output_dir, filename[:-4]+"_noise.png")
        img_B_output_path = os.path.join(img_B_output_dir, filename[:-4]+"_noise.png")
        mask_output_path = os.path.join(mask_output_dir, filename[:-4]+"_noise.png")

        noisy_image_A = image_A.copy()
        mean = 0
        stddev = 0.5  # noise level
        added_noise = np.random.normal(mean, stddev, image_A.shape).astype(np.uint8)
        noisy_image_A = cv2.add(image_A, added_noise)
        noisy_image_B = cv2.add(image_B, added_noise)

        cv2.imwrite(img_A_output_path, noisy_image_A)
        cv2.imwrite(img_B_output_path, noisy_image_B)
        cv2.imwrite(mask_output_path, mask)

# %%
input_dir = "Dataset_ROBOFLOW_cropped"
output_dir = "Dataset_ROBOFLOW_augmented"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)
for folder in ["A", "B", "label", "list"]:
    fold_path = os.path.join(output_dir, folder).replace('\\', '/')
    os.makedirs(fold_path, exist_ok=True)


for filename in os.listdir(os.path.join(input_dir,"A")):
    file_paths = {}
    output_sub_dirs = {}
    for folder in ["A", "B", "label"]:
        file_paths[folder] = os.path.join(input_dir, folder, filename).replace('\\', '/')
        output_sub_dirs[folder] = os.path.join(output_dir, folder).replace('\\', '/')

    if "test" in filename[:5]: # in test folder no augmentations
        save_and_apply_transformations(img_A_path=file_paths["A"], img_B_path=file_paths["B"], mask_path=file_paths["label"],
                                img_A_output_dir=output_sub_dirs["A"], img_B_output_dir=output_sub_dirs["B"], mask_output_dir=output_sub_dirs["label"],
                                copy=True)
        continue
    
    # For each of the images in the folder create 3 images with different rotations
    rotation_angles = [90,180,270]
    save_and_apply_transformations(img_A_path=file_paths["A"], img_B_path=file_paths["B"], mask_path=file_paths["label"],
                                   img_A_output_dir=output_sub_dirs["A"], img_B_output_dir=output_sub_dirs["B"], mask_output_dir=output_sub_dirs["label"],
                                   copy=True, rotations=True, rotation_angles=rotation_angles)

# %%
output_dir = "Dataset_ROBOFLOW_augmented"

update_filenames_list(input_folder=os.path.join(output_dir, 'A'), output_folder=os.path.join(output_dir, 'list'))
